# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Jarrod Butts**
# Aspiring Data Scientist

# %% [markdown]
# *"I am interested in data science because it is an intellectually stimulating field that looks to improve life in a variety of ways. The multiplicity of uses is a bit overwhelming, but also inspiring."*

# %% [markdown]
# ### In the cell below, I execute a simple mathematical operation ###

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ---
# [tree](https://cdn.pixabay.com/photo/2016/05/05/02/37/sunset-1373171_1280.jpg)
# ~~The world is flat.~~
